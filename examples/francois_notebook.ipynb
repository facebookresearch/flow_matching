# %%
import torch 
from torch import nn, Tensor

import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples = 1000, noise=0.1)

# %%
# Display first 5 samples
print("First 5 samples:")
for i in range(1):
    print(f"Sample {i+1}: features = {X[i]}, label = {y[i]}")

# Convert to PyTorch Tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

# Visualize samples
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("Samples from the Make-Moons Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# First 5 samples:
# Sample 1: features = [ 0.87337837 -0.61056658], label = 1

# %%
from einops import rearrange, repeat

class Flow(nn.Module):
    def __init__(self, dim: int = 2, h: int = 64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim + 1, h), nn.ELU(),
            nn.Linear(h, h), nn.ELU(),
            nn.Linear(h, h), nn.ELU(),
            nn.Linear(h, dim))
    
    def forward(self, t: Tensor, x_t: Tensor) -> Tensor:
        return self.net(torch.cat((t, x_t), -1))
    
    def step(self, x_t: Tensor, t_start: Tensor, t_end: Tensor):

        
    
        
        
        
model = Flow(dim = 2, h = 64)


d = 2
b = 4
x_t = torch.randn([b, d])
t = torch.rand(size = [b, 1])

        
num_steps = 10

x_0 = torch.rand(300, 2)
x_0.shape
ts = torch.linspace(start = 0.0, end = 1.0, steps = num_steps)
i = 4
t_start = ts[i]
t_end = ts[i+1]

model.step(x_t = x_0, t_start = t_start, t_end = t_end)
# Out:
# tensor([[0.3094, 0.5548],
#         [0.0207, 0.6423],
#         [0.1342, 0.3072],
#         [0.1270, 0.9694],
#         [0.7196, 0.0140],
#         [0.6385, 0.6864],
#         [0.9130, 0.0929],
#         [0.0984, 0.3774],
#         [0.8551, 0.3222],
#         [0.8998, 0.5134],
#         [0.1630, 0.4995],
#         [0.3011, 0.7151],
#         [0.1593, 0.4558],
#         [0.8179, 0.5934],
#         [0.6838, 0.7844],
#         [0.7620, 0.6929],
#         [0.9342, 0.3775],
#         [0.2465, 0.8923],
#         [0.0656, 0.3978],
#         [0.4744, 0.3602],
#         [0.9870, 0.4373],
#         [0.5046, 0.4943],
#         [0.1054, 0.9204],
#         [0.0927, 0.5508],
#         [0.2770, 0.6029],
#         [0.7063, 0.5884],
#         [0.6815, 0.4210],
#         [0.8258, 0.2749],
#         [0.7949, 0.7359],
#         [0.3808, 0.2931],
#         [0.6805, 0.0178],
#         [0.1322, 0.2299],
#         [0.1697, 0.4989],
#         [0.1750, 0.0339],
#         [0.9730, 0.7397],
# ...
